# %%
# df = pd.read_csv("../Fall Data (New)/Same floor falls/TESTING_ML_BB_v75.txt",header=None)
import pandas as pd
import numpy as np
df = pd.read_csv("../../Fall Data (New)/TESTING_ML_v22.txt",header=None)
# fall_time = df[df[1].isna()]
df = df[df[1].notna()]



ax = np.array(df[1])
ay = np.array(df[2])
az = np.array(df[3])

time = np.array(df[0],dtype=int)
# aax = ax[np.arange(0,ax.shape[0],20)]
# aay = ay[np.arange(0,ax.shape[0],20)]
# aaz = az[np.arange(0,ax.shape[0],20)]
# time = time[np.arange(0,ax.shape[0],20)]
s =np.sqrt(ax**2 + ay**2 + az**2)

import matplotlib.pyplot as plt

# one = [1 for i in range(len(s))]
plt.xticks(np.arange(time[0], time[-1], 500),fontsize=5)
plt.plot(time, s)
# plt.plot(time, one)

plt.ylim(0, 15)
plt.show()

i = (np.argmax(s))
plt.ylim(0, 2)
print(time[i])
plt.plot(time[i-450:i+450], s[i-450:i+450])
plt.show()
# Out:
# 9236

# %%
import os
import pandas as pd
import numpy as np
j = 0
for dirpath, dirnames, filenames in os.walk("../../Fall Data (New)/"):
    for filename in [f for f in filenames if f.endswith(".txt")]:
        df = pd.read_csv(os.path.join(dirpath, filename),header=None)
        fall_time = df[df[1].isna()]
        df = df[df[1].notna()]
        ax = np.array(df[1])
        ay = np.array(df[2])
        az = np.array(df[3])
        gx = np.array(df[4])
        gy = np.array(df[5])
        gz = np.array(df[6])
        time = np.array(df[0])
        a = np.sqrt(ax**2 + ay**2 + az**2)
        if filename[0] == "A":
            continue
        elif filename[11] == "B":
            print(j)
            j += 1
           
            import matplotlib.pyplot as plt

            # one = [1 for i in range(len(s))]
            plt.xticks(np.arange(time[0], time[-1], 500),fontsize=5)
            # plt.plot(time, a)
            # plt.plot(time, one)

            # plt.ylim(0, 15)
            # plt.show()
            
            i = (np.argmax(a))
            plt.ylim(0, 2)
            # print(time[i])
            plt.plot(time[i-450:i+450], a[i-450:i+450])
            print((a[i-450:i+450] > 4.5).sum())
            plt.show()
        else:
            continue
# Out:
# 0
# 13
# 1
# 16
# 2
# 16
# 3
# 17
# 4
# 19
# 5
# 23
# 6
# 20
# 7
# 0
# 8
# 10
# 9
# 13
# 10
# 10
# 11
# 20
# 12
# 0
# 13
# 16
# 14
# 0
# 15
# 6
# 16
# 20
# 17
# 9
# 18
# 6
# 19
# 6
# 20
# 16
# 21
# 15
# 22
# 0
# 23
# 17
# 24
# 16
# 25
# 16
# 26
# 8
# 27
# 9

# %%
import os
import pandas as pd
import numpy as np
j = 0
for dirpath, dirnames, filenames in os.walk("../../Fall Data (New)/"):
    for filename in [f for f in filenames if f.endswith(".txt")]:
        df = pd.read_csv(os.path.join(dirpath, filename),header=None)
        fall_time = df[df[1].isna()]
        df = df[df[1].notna()]
        ax = np.array(df[1])
        ay = np.array(df[2])
        az = np.array(df[3])
        gx = np.array(df[4])
        gy = np.array(df[5])
        gz = np.array(df[6])
        time = np.array(df[0])
        a = np.sqrt(ax**2 + ay**2 + az**2)
        if filename[0] == "A":
            xx = np.max(a)
            if xx > 4.5:
                print(filename)
                plt.plot(time, a)
                plt.show()
        elif filename[11] == "B":
            continue
        else:
            # print(j)
            # j += 1
           
            # import matplotlib.pyplot as plt

            # # one = [1 for i in range(len(s))]
            # plt.xticks(np.arange(time[0], time[-1], 500),fontsize=5)
            # # plt.plot(time, a)
            # # plt.plot(time, one)

            # # plt.ylim(0, 15)
            # # plt.show()
            
            # i = (np.argmax(a))
            # plt.ylim(0, 2)
            # # print(time[i])
            # plt.plot(time[i-450:i+450], a[i-450:i+450])
            # print((a[i-450:i+450] > 4.5).sum())
            # plt.show()
            continue
# Out:
# ADL_TESTING_ML_v14.txt
# ADL_TESTING_ML_v33.txt
# ADL_TESTING_ML_v37.txt
# ADL_TESTING_ML_v41.txt
# ADL_TESTING_ML_v42.txt
# ADL_TESTING_ML_v48.txt
# ADL_TESTING_ML_v6.txt
# ADL_TESTING_ML_v7.txt
